# %%
pip list
# Out:
# Package                            Version
# ---------------------------------- ----------
# -cipy                              1.5.2
# -illow                             6.2.0
# absl-py                            0.9.0
# aiohttp                            3.8.4
# aiosignal                          1.3.1
# alabaster                          0.7.12
# altgraph                           0.17
# anaconda-client                    1.7.2
# anaconda-navigator                 1.9.7
# anaconda-project                   0.8.3
# anyio                              3.7.0
# appdirs                            1.4.3
# APScheduler                        3.6.3
# asgiref                            3.4.1
# asn1crypto                         1.0.1
# astor                              0.8.0
# astroid                            2.3.1
# astropy                            3.2.1
# async-timeout                      4.0.2
# asynctest                          0.13.0
# atomicwrites                       1.3.0
# ...

# %%
import pandas as pd

# %%
df = pd.read_excel("./白蛇2.xlsx")
df.head(10)
# Out:
#            id           用户名    城市   评分  \
# 0  1142669584        淇桐糯米饭啦    来宾  5.0
# 1  1142662178   LnV14610189    西宁  5.0
# 2  1142666877  Alo861902585    广州  5.0
# 3  1142660216            Y。    西安  4.0
# 4  1142669423         想为你揽月    凤台  5.0
# 5  1142669422       啊卡哇啊呀啊呀    日照  5.0
# 6  1142669404       Lfz9696    永州  4.5
# 7  1142666812      Tenacity    广州  4.0
# 8  1142661206  CQE579669148  乌鲁木齐  5.0
# 9  1142668420         胖胖的唢呐    伊犁  5.0
#
#                                                   评论                 评论时间
# 0                                剧情非常有吸引力，看个动画片给了我惊喜  2021-08-31 23:56:30
# 1                                             画面感超强！  2021-08-31 23:36:00
# 2                                        和一衔接的很不错，精彩  2021-08-31 23:34:41
# 3           画面人物没的说，你永远可以相信追光。剧情还算顺畅整体节奏也还可以，推荐观看——！  2021-08-31 23:30:56
# 4  不错哦，虽然小青小白的执念有一丢丢丢丢丢牵强（还好）。如果能细说一下牛魔的执念剧情会更完美，...  2021-08-31 23:27:28
# 5                                     不错不错，感觉越来越有看头了  2021-08-31 23:27:12
# ...

# %%
# 数据大小
df.shape
# Out:
# (20584, 6)

# %%
# 数据类型信息
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20584 entries, 0 to 20583
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   id      20584 non-null  int64
#  1   用户名     20583 non-null  object
#  2   城市      20584 non-null  object
#  3   评分      20584 non-null  float64
#  4   评论      20584 non-null  object
#  5   评论时间    20584 non-null  object
# dtypes: float64(1), int64(1), object(4)
# memory usage: 965.0+ KB

# %%
# 用户名存在缺失 用"未知填充"  inplace=True  在原数据上进行更改
df["用户名"].fillna("未知", inplace=True)

# %%
# 计算空值的个数
df.isnull().sum()
# Out:
# id      0
# 用户名     0
# 城市      0
# 评分      0
# 评论      0
# 评论时间    0
# dtype: int64
